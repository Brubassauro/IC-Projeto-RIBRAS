# %%
from google.colab import files

He=str(files.upload())
Li3=str(files.upload())
Li2=str(files.upload())
He2=str(files.upload())
He1=str(files.upload())
# Out:
#      <input type="file" id="files-ce9e0300-39ce-4123-bd49-3ccb3e8e8be2" name="files[]" multiple disabled />
#      <output id="result-ce9e0300-39ce-4123-bd49-3ccb3e8e8be2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6He.txt to 6He.txt
#      <input type="file" id="files-cc94d618-52a5-409d-8f17-5a3bc077f302" name="files[]" multiple disabled />
#      <output id="result-cc94d618-52a5-409d-8f17-5a3bc077f302">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 7Li3+.txt to 7Li3+.txt
#      <input type="file" id="files-e621c886-e12e-472a-a88b-2ba176cfe3eb" name="files[]" multiple disabled />
# ...

# %%
li=str(files.upload())
# Out:
#      <input type="file" id="files-4de73564-3746-4c7b-a0c7-24ba051ebbcd" name="files[]" multiple disabled />
#      <output id="result-4de73564-3746-4c7b-a0c7-24ba051ebbcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Li2.0.txt to Li2.0.txt

# %%
import numpy as np
import matplotlib.pyplot as plt

def lista(T):
  t1=T.replace('\r\n','')
  t1=t1.replace('\\r\\n','')
  t1=t1.split(',')
  t2=[]
  for i in range(len(t1)-2):
    t2+=[float(t1[i+1])]
  return(t2)

def graf(A,c,d):
  for n in range(4):
    x=[]
    y=[]
    for i in range(int((153-4)/2)):
      x+=[A[i*2+n*int(153-3)]]
      y+=[A[1+i*2+n*int(153-3)]]
    plt.plot(x,y,color=c,linewidth=1)
  x=[]
  y=[]
  for i in range(int((153-4)/2)):
    x+=[A[i*2+4*int(153-3)]]
    y+=[A[1+i*2+4*int(153-3)]]
  plt.plot(x,y,color=c,label=d,linewidth=1)

#graf(lista(Li2),'red','7Li2+')  
#graf(lista(He1),'green','4He+')
graf(lista(He),'fuchsia','6He')
#graf(lista(He2),'orange','4He2+')
graf(lista(li),'blue','7Li')
plt.title('Trajetórias no solenóide (35.4A)')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.legend()
plt.grid()
plt.xlim(0,3)
plt.ylim(0,0.12)
plt.show()

graf(lista(He),'fuchsia','6He')
plt.title('Trajetórias do 6He no solenóide (35.4A)')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.grid()
plt.xlim(0,3)
plt.ylim(0,0.12)
plt.show()
